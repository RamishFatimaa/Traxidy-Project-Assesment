# %%
# !pip install pycaret fastapi uvicorn

# %%
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %%
import pandas as pd
import numpy as n

df = pd.read_csv("actions.csv")
df
# Out:
#        id  creator_id  project_id  issue_id  owner_contact_id  \
# 0       1           2           4         1               6.0
# 1       5           2           4         4               8.0
# 2       6           2           4         1               7.0
# 3       8           2           4         4              12.0
# 4       9           2           2         5              13.0
# ..    ...         ...         ...       ...               ...
# 980  1289           2         231      1185             666.0
# 981  1290           2         231      1186             667.0
# 982  1291           2         231      1187             667.0
# 983  1292           2         231      1188               NaN
# 984  1293           2         231      1189             668.0
#
#     owner_contact_name action_identifier  \
# 0        T.J. Shalmark             I1-A1
# 1           Sal Nuberg             I4-A1
# 2           Jerri Shaw             I1-A3
# 3       Janet Dietrich             I4-A2
# ...

# %%
from pycaret.regression import *

s = setup(df, target = 'progress')
# Out:
# <style type="text/css">
# #T_a8533_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a8533">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8533_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a8533_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8533_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8533_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a8533_row0_col1" class="data row0 col1" >7605</td>
#     </tr>
#     <tr>
#       <th id="T_a8533_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8533_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a8533_row1_col1" class="data row1 col1" >progress</td>
#     </tr>
#     <tr>
#       <th id="T_a8533_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_fbc60 th {
#   text-align: left;
# }
# ...

# %%
df2 = pd.read_csv("action_histories.csv")
df2
# Out:
#         id  creator_id  action_id  owner_contact_id  \
# 0        1         NaN          1               6.0
# 1        2         NaN          1               6.0
# 2        6         NaN          5               8.0
# 3        7         NaN          6               7.0
# 4       10         NaN          5               8.0
# ...    ...         ...        ...               ...
# 1918  2341         NaN       1289             666.0
# 1919  2342         NaN       1290             667.0
# 1920  2343         NaN       1291             667.0
# 1921  2344         NaN       1292               NaN
# 1922  2345         NaN       1293             668.0
#
#                                             description    due_date  \
# 0     Most of what we are doing is to receive more t...  2021-12-10
# 1     Most of what we are doing is to receive more t...  2021-12-10
# 2     Most of what we are doing is to receive more t...  2021-11-29
# ...

# %%
from pycaret.regression import *

s = setup(df2, target = 'progress')
# Out:
# <style type="text/css">
# #T_4ad53_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4ad53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ad53_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4ad53_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ad53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ad53_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4ad53_row0_col1" class="data row0 col1" >8268</td>
#     </tr>
#     <tr>
#       <th id="T_4ad53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ad53_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4ad53_row1_col1" class="data row1 col1" >progress</td>
#     </tr>
#     <tr>
#       <th id="T_4ad53_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_58b7b th {
#   text-align: left;
# }
# ...

# %%
df3 = pd.read_csv("updated_changes.csv")
df3
# Out:
#     id  creator_id  project_id  approver_contact_id change_identifier  \
# 0    1           2           4                158.0               CR1
# 1    2           2           4                 76.0               CR2
# 2    3           2           4                  8.0               CR3
# 3    4           2           4                  NaN               CR4
# 4    5           6          12                  NaN               CR1
# 5    6           6          12                  NaN               CR2
# 6    7           2           2                  1.0               CR1
# 7    8           2           2                  1.0               CR2
# 8    9           2           2                  1.0               CR3
# 9   10          42          25                 53.0               CR1
# 10  11          46          36                 66.0               CR1
# 11  12          46          36                 67.0               CR2
# ...

# %%
from pycaret.regression import *

s = setup(df3, target = 'impact_days')
# Out:
# <style type="text/css">
# #T_f0cac_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f0cac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0cac_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f0cac_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0cac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0cac_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f0cac_row0_col1" class="data row0 col1" >4104</td>
#     </tr>
#     <tr>
#       <th id="T_f0cac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0cac_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f0cac_row1_col1" class="data row1 col1" >impact_days</td>
#     </tr>
#     <tr>
#       <th id="T_f0cac_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_91254 th {
#   text-align: left;
# }
# ...

# %%
df4 = pd.read_csv("contacts.csv") ###No Need for Alogrithm for this table
df4
# Out:
#       id  creator_id  company_id first_name last_name       full_name  \
# 0      1           2           2     Janice      Wong     Janice Wong
# 1      2           2           2      Steve     Sammy     Steve Sammy
# 2      3           2           2    Richard    Austin  Richard Austin
# 3      4           2           2        Jan  Dietrich    Jan Dietrich
# 4      5           2           2      Reggy  Ralphson  Reggy Ralphson
# ..   ...         ...         ...        ...       ...             ...
# 275  288           2           2        Sam     Smith       Sam Smith
# 276  292           2           2       stab    jsghfs     stab jsghfs
# 277  293           2           2      Bobby   Builder   Bobby Builder
# 278  294           2           2  Wallimina      Good  Wallimina Good
# 279  295           2           2     Roofus       Rep      Roofus Rep
#
#                          email     company_name   department    phone_number  \
# ...

# %%
df5 = pd.read_csv("update_gyr_constraints.csv")
df5
# Out:
#        id  creator_id  project_id constraint status comments previous_status  \
# 0       1           2           1    overall  green      NaN             NaN
# 1       2           2           1      scope  green      NaN             NaN
# 2       3           2           1     budget  green      NaN             NaN
# 3       4           2           1   schedule  green      NaN             NaN
# 4       5           2           2    overall  green      NaN             NaN
# ..    ...         ...         ...        ...    ...      ...             ...
# 994  1155           2         230   schedule  green      NaN             NaN
# 995  1156           2         231    overall  green      NaN             NaN
# 996  1157           2         231      scope  green      NaN             NaN
# 997  1158           2         231     budget  green      NaN             NaN
# 998  1159           2         231   schedule  green      NaN             NaN
#
# ...

# %%
from pycaret.regression import *

s = setup(df5, target = 'num_status')
# Out:
# <style type="text/css">
# #T_21359_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_21359">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21359_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_21359_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21359_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21359_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_21359_row0_col1" class="data row0 col1" >515</td>
#     </tr>
#     <tr>
#       <th id="T_21359_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21359_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_21359_row1_col1" class="data row1 col1" >num_status</td>
#     </tr>
#     <tr>
#       <th id="T_21359_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_21c7b th {
#   text-align: left;
# }
# ...

# %%
df6 = pd.read_csv("update_milestones.csv")
df6
# Out:
#       id  project_id  creator_id                      description gyr_status  \
# 0      1           4           2                    milestone one   complete
# 1      2           4           2                    milestone two      green
# 2      3           4           2                  milestone three        red
# 3      4           4           2                   milestone four      green
# 4      5           4           2                    milestone 2.2   complete
# ..   ...         ...         ...                              ...        ...
# 371  476         230           2  Roof Complete and Shed Complete      green
# 372  477         231           2               Materials obtained      green
# 373  478         231           2              Foundation complete      green
# 374  479         231           2       Wall Installation Complete      green
# 375  480         231           2  Roof Complete and Shed Complete      green
#
# ...

# %%
from pycaret.regression import *

s = setup(df6, target = 'num_gyr_status')
# Out:
# <style type="text/css">
# #T_605a0_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_605a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_605a0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_605a0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_605a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_605a0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_605a0_row0_col1" class="data row0 col1" >7883</td>
#     </tr>
#     <tr>
#       <th id="T_605a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_605a0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_605a0_row1_col1" class="data row1 col1" >num_gyr_status</td>
#     </tr>
#     <tr>
#       <th id="T_605a0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_174eb th {
#   text-align: left;
# }
# ...

# %%
df7 = pd.read_csv("mitigations.csv")###No Need for Alogrithm for this table
df7
# Out:
#     id  creator_id  risk_id  \
# 0    1           2        6
# 1    2           2        2
# 2    4           2        5
# 3    5          42       15
# 4    6          32       16
# 5    7          46       17
# 6    8          46       18
# 7    9           2       11
# 8   10           2        7
# 9   11           2       22
# 10  12           2       24
# 11  13           2       19
# 12  14           2       23
# 13  15           2       25
# 14  16           2       25
# 15  17           2       26
# 16  18          52        6
# 17  19          35       33
# 18  20          35       35
# 19  21          35       35
# 20  22          35       34
# 21  23           2        6
# 22  24           2        9
# 23  25           2       38
# 24  26           2        4
# 25  27           2        1
# 26  28           6       39
# 27  29           6       40
# 28  30           6       41
# 29  31           6       40
# 30  32          56       43
# 31  33           2       38
# ...

# %%
df8 = pd.read_csv("project_contacts.csv")###No Need for Alogrithm for this table
df8
# Out:
#       id  creator_id  contact_id  project_id first_name last_name  \
# 0      1           2           1           2     Janice      Wong
# 1      2           2           2           3      Steve     Sammy
# 2      3           2           3           3    Richard    Austin
# 3      4           2           4           3        Jan  Dietrich
# 4      5           2           5           4      Reggy  Ralphson
# ..   ...         ...         ...         ...        ...       ...
# 528  664           2         295         230     Roofus       Rep
# 529  665           2         219         231      Steve   McBroom
# 530  666           2         293         231      Bobby   Builder
# 531  667           2         294         231  Wallimina      Good
# 532  668           2         295         231     Roofus       Rep
#
#           full_name                      email     company_name   department  \
# 0       Janice Wong            JW@rogattnet.au  Rogatt Networks          NaN
# ...

# %%
df9 = pd.read_csv("revised_end_date_histories.csv")
df9
# Out:
#     id  project_id revised_date  revised_work_days           created_at  \
# 0    1           4   2022-06-09                156  2021-11-29 12:51:40
# 1    2           3   2022-08-17                709  2021-12-19 06:30:04
# 2    3          36   2022-02-16                  9  2022-02-28 03:47:19
# 3    4           2   2022-05-20                123  2022-03-05 09:08:16
# 4    5           4   2022-06-13                158  2022-03-05 09:23:57
# 5    6           4   2022-06-01                150  2022-03-05 09:24:05
# 6    7           4   2022-07-14                181  2022-03-05 09:24:17
# 7    8           4   2022-07-22                187  2022-03-05 09:38:09
# 8    9           4   2022-08-01                193  2022-03-05 09:38:45
# 9   10          60   2022-08-19                 39  2022-03-14 06:35:41
# 10  11           4   2022-08-24                210  2022-03-23 11:23:45
# 11  12           4   2022-11-30                280  2022-03-28 08:00:30
# ...

# %%
from pycaret.regression import *

s = setup(df9, target = 'revised_work_days')
# Out:
# <style type="text/css">
# #T_a5fb2_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5fb2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5fb2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5fb2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5fb2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5fb2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a5fb2_row0_col1" class="data row0 col1" >8684</td>
#     </tr>
#     <tr>
#       <th id="T_a5fb2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5fb2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5fb2_row1_col1" class="data row1 col1" >revised_work_days</td>
#     </tr>
#     <tr>
#       <th id="T_a5fb2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_68e86 th {
#   text-align: left;
# }
# ...

# %%
df10 = pd.read_csv("risks.csv")
df10
# Out:
#       id  creator_id  project_id  owner_contact_id  owner_contact_name  \
# 0      1           2           4               6.0       T.J. Shalmark
# 1      2           2           4               NaN         Steve Sammy
# 2      4           2           4               8.0          Sal Nuberg
# 3      5           2           4               5.0      Reggy Ralphson
# 4      6           2           4             111.0  Traxidy Gmail Acct
# ..   ...         ...         ...               ...                 ...
# 365  522           2         230               NaN                 NaN
# 366  523           2         230               NaN                 NaN
# 367  524           2         231               NaN                 NaN
# 368  525           2         231               NaN                 NaN
# 369  526           2         231               NaN                 NaN
#
#     risk_identifier                                          statement  \
# ...

# %%
from pycaret.regression import *

s = setup(df10, target = 'impact')
# Out:
# <style type="text/css">
# #T_56995_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_56995">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56995_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_56995_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56995_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56995_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_56995_row0_col1" class="data row0 col1" >2762</td>
#     </tr>
#     <tr>
#       <th id="T_56995_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56995_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_56995_row1_col1" class="data row1 col1" >impact</td>
#     </tr>
#     <tr>
#       <th id="T_56995_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a7e07 th {
#   text-align: left;
# }
# ...

# %%
df11 = pd.read_csv("user_infos.csv")
df11
# Out:
#     user_id user_project_is_for       usual_role country  \
# 0         1                work          Manager     NaN
# 1         2                work          Manager     NaN
# 2         3                 NaN              NaN     NaN
# 3         4                 NaN              NaN     NaN
# 4         5            personal  Project Manager  Canada
# ..      ...                 ...              ...     ...
# 91       92                 NaN              NaN     NaN
# 92       93                 NaN              NaN     NaN
# 93       94            personal          Manager  Canada
# 94       95                work  Project Manager  Canada
# 95       96                 NaN              NaN     NaN
#
#     uses_project_management_office average_project_team_size  \
# 0                              0.0                      6_10
# 1                              0.0                      6_10
# 2                              NaN                       NaN
# ...

# %%
df13 = pd.read_csv("update_snapshots.csv")
df13
# Out:
#           id  project_id        date overall_gyr_status  open_issues_count  \
# 0          1           1  2021-11-23              green                  0
# 1          2           2  2021-11-23              green                  0
# 2          3           3  2021-11-23              green                  0
# 3          4           1  2021-11-24              green                  0
# 4          5           2  2021-11-24              green                  0
# ...      ...         ...         ...                ...                ...
# 15262  15263         135  2024-01-30              green                 65
# 15263  15264         202  2024-01-30              green                  0
# 15264  15265         229  2024-01-30              green                  0
# 15265  15266         230  2024-01-30              green                  0
# 15266  15267         231  2024-01-30              green                  0
#
# ...

# %%
from pycaret.regression import *

s = setup(df13, target = 'num_overall_gyr_status')
# Out:
# <style type="text/css">
# #T_5c63d_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5c63d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c63d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5c63d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c63d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c63d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5c63d_row0_col1" class="data row0 col1" >2491</td>
#     </tr>
#     <tr>
#       <th id="T_5c63d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c63d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5c63d_row1_col1" class="data row1 col1" >num_overall_gyr_status</td>
#     </tr>
#     <tr>
#       <th id="T_5c63d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_68000 th {
#   text-align: left;
# }
# ...

# %%
import pickle as p

# %%
pickle_out=open("project_management.pkl", "wb")
pickle.dump(classifier, pickle_out)
pickle_out.close()##Dont run this file
